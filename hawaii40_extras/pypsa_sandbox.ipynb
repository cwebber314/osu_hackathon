# %%
import pandas as pd
import pdb
import  io
import pypsa

# %%
import hawaii40_case

# %%
ppc = hawaii40_case.hawaii40_ppc()
network = pypsa.Network()
network.import_from_pypower_ppc(ppc)
# Out:
# WARNING:pypsa.network.io:Warning: Note that when importing from PYPOWER, some PYPOWER features not supported: areas, gencosts, component status
# WARNING:pypsa.network.io:Warning, some transformers have a tap ratio of 0., setting the tap ratio of these to 1.
# WARNING:pypsa.network.io:The following Transformer have buses which are not defined:
# Index(['T0', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8'], dtype='object')

# %%
network.plot.map(bus_sizes=5e-4,)
# Out:
# {'nodes': {'Bus': <matplotlib.collections.PatchCollection at 0x2306e482420>},
#  'branches': {'Transformer': <matplotlib.collections.LineCollection at 0x2306e47d370>,
#   'Line': <matplotlib.collections.LineCollection at 0x2306e2c7110>},
#  'flows': {}}
