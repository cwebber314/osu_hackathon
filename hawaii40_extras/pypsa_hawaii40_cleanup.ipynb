# %% [markdown]
# # Hawaii40 Cleanup
#
# Move the Hawaii40 case from the Texas A&M repo to pypsa.

# %%
import pandas as pd
import pdb
import  io
import pypsa
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import hawaii40_case

# %%
import importlib
importlib.reload(hawaii40_case)
# Out:
# <module 'hawaii40_case' from 'C:\\cwebber\\osu_hackathon\\hawaii40_extras\\hawaii40_case.py'>

# %%
# The .m file makes it easy to import the case, but doesn't contain the GPS coordinates
ppc = hawaii40_case.hawaii40_ppc()
network = pypsa.Network()
network.import_from_pypower_ppc(ppc)
# Out:
# WARNING:pypsa.network.io:Warning: Note that when importing from PYPOWER, some PYPOWER features not supported: areas, gencosts, component status

# %%
# We can still plot the network, but there's no GIS data
network.plot.map(bus_sizes=5e-5, title="Hawaii 40 (No coordinates)");

# %% [markdown]
# # Explore network

# %%
ppc['bus'][0:1]
# Out:
# array([[  1.       ,   1.       ,   0.       ,   0.       ,   0.       ,
#           0.       ,   1.       ,   0.9935453,  -1.119907 , 138.       ,
#           1.       ,   1.1      ,   0.9      ,   5.22     ,   0.       ,
#           0.       ,   0.       ]])

# %%
network.buses.head()
# Out:
#      v_nom type    x    y carrier unit location  v_mag_pu_set  v_mag_pu_min  \
# Bus
# 1    138.0       0.0  0.0      AC                    0.993545           0.9
# 2     69.0       0.0  0.0      AC                    1.000000           0.9
# 3     69.0       0.0  0.0      AC                    0.984548           0.9
# 4     69.0       0.0  0.0      AC                    0.978800           0.9
# 5    138.0       0.0  0.0      AC                    0.988985           0.9
#
#      v_mag_pu_max control generator sub_network     Pd   Qd   Gs   Bs  area  \
# Bus
# 1             1.1      PQ                         0.00  0.0  0.0  0.0   1.0
# 2             1.1      PV                        60.70  0.0  0.0  0.0   1.0
# 3             1.1      PQ                        59.39  0.0  0.0  0.0   1.0
# 4             1.1      PQ                        22.47  0.0  0.0  0.0   1.0
# 5             1.1      PQ                         0.00  0.0  0.0  0.0   1.0
#
#      v_ang_set  zone
# Bus
# 1    -1.119907   1.0
# 2    -3.927372   1.0
# 3    -4.731145   1.0
# 4    -5.745870   1.0
# 5    -2.069792   1.0

# %% [markdown]
# ## Merge Busses and Substations from PowerWorld
#
# Now add GPS coordinates for busses. See the [bus docs](https://pypsa.readthedocs.io/en/latest/user-guide/components.html#bus)

# %%
# Get the full data from the PowerWorld AUX data 
buses = pd.read_csv('hawaii40_bus.csv')
buses.head()
# Out:
#    Number         Name  NomkV Slack  NomB  NomG       Vpu    Vangle  \
# 0       1     ALOHA138  138.0   NO    0.0   0.0  0.993545 -1.119907
# 1       2      ALOHA69   69.0   NO    0.0   0.0  0.991225 -3.927372
# 2       3     FLOWER69   69.0   NO    0.0   0.0  0.984548 -4.731145
# 3       4       WAVE69   69.0   NO    0.0   0.0  0.978800 -5.745870
# 4       5  HONOLULU138  138.0   NO    0.0   0.0  0.988985 -2.069793
#
#    DCLossMultiplier  AreaNumber  ...  Latitude  Longitude  TopologyBusType  \
# 0               1.0           1  ...       NaN        NaN    BusbarSection
# 1               1.0           1  ...       NaN        NaN    BusbarSection
# 2               1.0           1  ...       NaN        NaN    BusbarSection
# 3               1.0           1  ...       NaN        NaN    BusbarSection
# 4               1.0           1  ...       NaN        NaN    BusbarSection
#
#    Priority EMSType EMSID DataMaintainerAssign  DataMaintainerInherit  \
# 0         0     NaN   NaN                  NaN                    YES
# 1         0     NaN   NaN                  NaN                    YES
# 2         0     NaN   NaN                  NaN                    YES
# 3         0     NaN   NaN                  NaN                    YES
# 4         0     NaN   NaN                  NaN                    YES
#
#    DataMaintainerInheritBlock  AllLabels
# 0                         NO         NaN
# 1                         NO         NaN
# 2                         NO         NaN
# 3                         NO         NaN
# 4                         NO         NaN
#
# [5 rows x 35 columns]

# %%
subs = pd.read_csv('hawaii40_substation.csv')
subs.head()
# Out:
#    Number      Name  IDExtra   Latitude   Longitude  DataMaintainerAssign  \
# 0       1     ALOHA        1  21.344246 -157.939889                   NaN
# 1       2    FLOWER        2  21.347927 -157.876274                   NaN
# 2       3      WAVE        3  21.293143 -157.848767                   NaN
# 3       4  HONOLULU        4  21.316548 -157.845053                   NaN
# 4       5      SURF        5  21.291518 -157.826869                   NaN
#
#   DataMaintainerInheritBlock
# 0                        NO
# 1                        NO
# 2                        NO
# 3                        NO
# 4                        NO

# %%
subs = subs[['Number', 'Latitude', 'Longitude']]
subs = subs.rename(columns={'Number': 'SubNumber'})

# %%
# Drop the Lat/Long from buses and get it from the Substation instead.
buses = buses.drop('Latitude', axis=1)
buses = buses.drop('Longitude', axis=1)
df = pd.merge(buses, subs, on='SubNumber')
df['Number'] = df['Number'].map(str) 
df = df.set_index('Number')

# %%
df.head()
# Out:
#                Name  NomkV Slack  NomB  NomG       Vpu    Vangle  \
# Number
# 1          ALOHA138  138.0   NO    0.0   0.0  0.993545 -1.119907
# 2           ALOHA69   69.0   NO    0.0   0.0  0.991225 -3.927372
# 3          FLOWER69   69.0   NO    0.0   0.0  0.984548 -4.731145
# 4            WAVE69   69.0   NO    0.0   0.0  0.978800 -5.745870
# 5       HONOLULU138  138.0   NO    0.0   0.0  0.988985 -2.069793
#
#         DCLossMultiplier  AreaNumber  ZoneNumber  ...  TopologyBusType  \
# Number                                            ...
# 1                    1.0           1           1  ...    BusbarSection
# 2                    1.0           1           1  ...    BusbarSection
# 3                    1.0           1           1  ...    BusbarSection
# 4                    1.0           1           1  ...    BusbarSection
# 5                    1.0           1           1  ...    BusbarSection
#
#         Priority  EMSType EMSID DataMaintainerAssign DataMaintainerInherit  \
# Number
# 1              0      NaN   NaN                  NaN                   YES
# 2              0      NaN   NaN                  NaN                   YES
# 3              0      NaN   NaN                  NaN                   YES
# 4              0      NaN   NaN                  NaN                   YES
# 5              0      NaN   NaN                  NaN                   YES
#
#         DataMaintainerInheritBlock  AllLabels   Latitude   Longitude
# Number
# 1                              NO         NaN  21.344246 -157.939889
# 2                              NO         NaN  21.344246 -157.939889
# 3                              NO         NaN  21.347927 -157.876274
# 4                              NO         NaN  21.293143 -157.848767
# 5                              NO         NaN  21.316548 -157.845053
#
# [5 rows x 34 columns]

# %% [markdown]
# # Add GPS to pypsa data

# %%
df.loc['1', 'Latitude']
# Out:
# np.float64(21.344246)

# %%
# Example of one data element
network.buses.loc['1', 'x']
# Out:
# np.float64(0.0)

# %%
network.buses['x'] = df['Longitude']
network.buses['y'] = df['Latitude']

# %%
# Add the name as a new field - this will stay with the buses dataframe during export/import
network.buses['name2'] = df['Name'] # extra column not in spec

# %%
fig, ax = plt.subplots(
    1, 1, subplot_kw={"projection": ccrs.EqualEarth()}, figsize=(8, 8)
)
network.plot.map(bus_sizes=5e-5, ax=ax, title="Hawaii 40 (with coordinates)");

# %% [markdown]
# # Export the new netwrk
#
# After we clean up the network we can export it to CSV

# %%
network.export_to_csv_folder(path='hawaii40_csv')
# Out:
# INFO:pypsa.network.io:Exported network 'Unnamed Network'saved to 'hawaii40_csv contains: transformers, shunt_impedances, generators, buses, loads, lines

# %%
=
